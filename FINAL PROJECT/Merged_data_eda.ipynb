# %% [markdown]
# ## ADNI Merged Data EDA

# %%
import pandas as pd
import numpy as np

# %%
"C:\Users\winsl0w\Documents\CS109_notebooks\FINAL PROJECT\Study Info\ADNIMERGE.csv"

# %%
df = pd.read_csv('Study Info/ADNIMERGE.csv', low_memory=False)
dd = pd.read_csv('Study Info/ADNIMERGE_DICT.csv')

# %%
df.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0     Male          ...               NaN     NaN  1.36665    NaN      NaN
# 1     Male          ...             239.7   22.83  1.08355    NaN      NaN
# 2     Male          ...             239.7   22.83  1.08355    NaN      NaN
# 3     Male          ...             239.7   22.83  1.08355    NaN      NaN
# 4     Male          ...             239.7   22.83  1.08355    NaN      NaN
#
#    Years_bl  Month_bl  Month   M           update_stamp
# ...

# %%
df.shape
# Out:
# (13632, 113)

# %%
# How much missing data do we have per column?
cols_with_nulls = df.columns[df.isnull().any()]

idx = []
missing = []
missing_pct = []

for col in cols_with_nulls:
    idx.append(col)
    missing.append(len(df[col][df[col].isnull()]))
    missing_pct.append(100 * len(df[col][df[col].isnull()])/len(df[col]))

missing_df = pd.DataFrame(np.array([missing, missing_pct]).T, index=idx, columns=['num missing', 'pct missing'])
missing_df.head()
# Out:
#        num missing  pct missing
# DX_bl         17.0     0.124725
# AGE            1.0     0.007337
# APOE4        377.0     2.765957
# FDG        10123.0    74.269993
# PIB        13407.0    98.363903

# %%
df.describe()
# Out:
#                 RID          SITE           AGE      PTEDUCAT         APOE4  \
# count  13632.000000  13632.000000  13631.000000  13632.000000  13254.000000
# mean    2394.221391     75.639305     73.677852     16.025455      0.532368
# std     1949.983450    116.331834      6.977834      2.813189      0.654409
# min        2.000000      2.000000     54.400000      4.000000      0.000000
# 25%      649.000000     21.000000     69.400000     14.000000      0.000000
# 50%     1378.000000     41.000000     73.600000     16.000000      0.000000
# 75%     4401.000000    116.000000     78.500000     18.000000      1.000000
# max     6582.000000    941.000000     91.400000     20.000000      2.000000
#
#                FDG         PIB         AV45        CDRSB       ADAS11  \
# count  3507.000000  223.000000  2510.000000  9778.000000  9683.000000
# mean      1.206657    1.783161     1.190519     2.102526    11.475344
# std       0.159250    0.422511     0.226900     2.834631     8.448760
# ...

# %%
missing_sorted = missing_df.sort_values(by=['pct missing'], ascending=False)
print(missing_sorted)
# Out:
#                           num missing  pct missing
# FLDSTRENG_bl                  13630.0   100.000000
# FLDSTRENG                     13630.0   100.000000
# PIB_bl                        13481.0    98.906823
# PIB                           13407.0    98.363903
# PTAU                          11260.0    82.611886
# ABETA                         11259.0    82.604549
# TAU                           11259.0    82.604549
# AV45                          11120.0    81.584740
# FDG                           10123.0    74.269993
# DIGITSCOR                      9830.0    72.120323
# EcogSPOrgan                    8012.0    58.782098
# EcogPtOrgan                    7946.0    58.297872
# EcogSPDivatt                   7907.0    58.011739
# MOCA                           7899.0    57.953045
# EcogSPVisspat                  7866.0    57.710932
# EcogPtDivatt                   7864.0    57.696258
# EcogPtVisspat                  7863.0    57.688921
# ...

# %%
df.FLDSTRENG
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#          ..
# 13600   NaN
# 13601   NaN
# 13602   NaN
# 13603   NaN
# 13604   NaN
# 13605   NaN
# 13606   NaN
# 13607   NaN
# 13608   NaN
# 13609   NaN
# 13610   NaN
# 13611   NaN
# 13612   NaN
# 13613   NaN
# 13614   NaN
# 13615   NaN
# 13616   NaN
# 13617   NaN
# 13618   NaN
# 13619   NaN
# 13620   NaN
# 13621   NaN
# 13622   NaN
# 13623   NaN
# 13624   NaN
# 13625   NaN
# 13626   NaN
# 13627   NaN
# 13628   NaN
# 13629   NaN
# Name: FLDSTRENG, Length: 13630, dtype: float64

# %%
df.dtypes
# Out:
# RID                        int64
# PTID                      object
# VISCODE                   object
# SITE                       int64
# COLPROT                   object
# ORIGPROT                  object
# EXAMDATE                  object
# DX_bl                     object
# AGE                      float64
# PTGENDER                  object
# PTEDUCAT                   int64
# PTETHCAT                  object
# PTRACCAT                  object
# PTMARRY                   object
# APOE4                    float64
# FDG                      float64
# PIB                      float64
# AV45                     float64
# ABETA                     object
# TAU                       object
# PTAU                      object
# CDRSB                    float64
# ADAS11                   float64
# ADAS13                   float64
# ADASQ4                   float64
# MMSE                     float64
# RAVLT_immediate          float64
# RAVLT_learning           float64
# ...
